# %%
import pandas as pd

# %%
"""
Para conseguir ler o arquivo precisamos configurar os atributos:
    sep = ';'
    encoding = 'ISO-8859-1'
    skiprows = 1

Comandos adicionais
    # thousands = '.'
    # decimal = ','
"""
raw_data = pd.read_csv("data/despesa_ceaps_2021.csv",
    encoding='ISO-8859-1',
    sep=';',
    skiprows=1,
    thousands='.',
    decimal=',')

# %%
raw_data.head(10)
# Out:
#     ANO  MES       SENADOR                                       TIPO_DESPESA  \
# 0  2021    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 1  2021    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 2  2021    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 3  2021    1  ACIR GURGACZ                Divulgação da atividade parlamentar
# 4  2021    1  ACIR GURGACZ                Divulgação da atividade parlamentar
# 5  2021    1  ACIR GURGACZ  Passagens aéreas, aquáticas e terrestres nacio...
# 6  2021    1  ACIR GURGACZ  Passagens aéreas, aquáticas e terrestres nacio...
# 7  2021    2  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 8  2021    2  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 9  2021    2  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
#
#              CNPJ_CPF                                         FORNECEDOR  \
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16827 entries, 0 to 16826
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ANO                16827 non-null  int64
#  1   MES                16827 non-null  int64
#  2   SENADOR            16827 non-null  object
#  3   TIPO_DESPESA       16827 non-null  object
#  4   CNPJ_CPF           16827 non-null  object
#  5   FORNECEDOR         16827 non-null  object
#  6   DOCUMENTO          16152 non-null  object
#  7   DATA               16827 non-null  object
#  8   DETALHAMENTO       9201 non-null   object
#  9   VALOR_REEMBOLSADO  16827 non-null  float64
#  10  COD_DOCUMENTO      16827 non-null  int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# conclusões do detalhamento acima:
# -

# %%
for i in raw_data.loc[0]:
    print(type(i))
# Out:
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.float64'>
# <class 'numpy.int64'>

# %% [markdown]
# ## Transformação dos dados
